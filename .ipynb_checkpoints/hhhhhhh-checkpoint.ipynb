# %%
import pandas as pd
train1 = pd.read_csv('1.csv')
n_list = train1["Number"]
country = train1["Country"]
year = train1["Year"]
city = train1["City"]

a = "第"
b = "届冬奥会是在"
c = "哪一年"
d = "哪个国家"
e = "哪个城市"
f = "举办的"

qlist = []
alist = []

for i in range(1,25,1):
    q1 = a+str(i)+b+c+f
    q2 = a+str(i)+b+d+f
    q3 = a+str(i)+b+e+f
    a1 = year[i]
    a2 = country[i]
    a3 = city[i]
    qlist.append(q1)
    qlist.append(q2)
    qlist.append(q3)
    alist.append(a1)
    alist.append(a2)
    alist.append(a3)
    
print (qlist)
print (alist)
data = {'question':qlist,
        'answer':alist}
df = pd.DataFrame(data,columns=['question','answer'])
writer = pd.ExcelWriter('./1.xlsx')
df.to_excel(writer, columns=['question','answer'], index=False,encoding='utf-8',sheet_name='Sheet1')
# Out:
# ['第1届冬奥会是在哪一年举办的', '第1届冬奥会是在哪个国家举办的', '第1届冬奥会是在哪个城市举办的', '第2届冬奥会是在哪一年举办的', '第2届冬奥会是在哪个国家举办的', '第2届冬奥会是在哪个城市举办的', '第3届冬奥会是在哪一年举办的', '第3届冬奥会是在哪个国家举办的', '第3届冬奥会是在哪个城市举办的', '第4届冬奥会是在哪一年举办的', '第4届冬奥会是在哪个国家举办的', '第4届冬奥会是在哪个城市举办的', '第5届冬奥会是在哪一年举办的', '第5届冬奥会是在哪个国家举办的', '第5届冬奥会是在哪个城市举办的', '第6届冬奥会是在哪一年举办的', '第6届冬奥会是在哪个国家举办的', '第6届冬奥会是在哪个城市举办的', '第7届冬奥会是在哪一年举办的', '第7届冬奥会是在哪个国家举办的', '第7届冬奥会是在哪个城市举办的', '第8届冬奥会是在哪一年举办的', '第8届冬奥会是在哪个国家举办的', '第8届冬奥会是在哪个城市举办的', '第9届冬奥会是在哪一年举办的', '第9届冬奥会是在哪个国家举办的', '第9届冬奥会是在哪个城市举办的', '第10届冬奥会是在哪一年举办的', '第10届冬奥会是在哪个国家举办的', '第10届冬奥会是在哪个城市举办的', '第11届冬奥会是在哪一年举办的', '第11届冬奥会是在哪个国家举办的', '第11届冬奥会是在哪个城市举办的', '第12届冬奥会是在哪一年举办的', '第12届冬奥会是在哪个国家举办的', '第12届冬奥会是在哪个城市举办的', '第13届冬奥会是在哪一年举办的', '第13届冬奥会是在哪个国家举办的', '第13届冬奥会是在哪个城市举办的', '第14届冬奥会是在哪一年举办的', '第14届冬奥会是在哪个国家举办的', '第14届冬奥会是在哪个城市举办的', '第15届冬奥会是在哪一年举办的', '第15届冬奥会是在哪个国家举办的', '第15届冬奥会是在哪个城市举办的', '第16届冬奥会是在哪一年举办的', '第16届冬奥会是在哪个国家举办的', '第16届冬奥会是在哪个城市举办的', '第17届冬奥会是在哪一年举办的', '第17届冬奥会是在哪个国家举办的', '第17届冬奥会是在哪个城市举办的', '第18届冬奥会是在哪一年举办的', '第
# ...

# %%
from urllib import request, parse
import json
 
def fanyi(content):
    req_url = 'http://fanyi.youdao.com/translate'
    head_data = {}
    head_data['Referer'] = 'http://fanyi.youdao.com/'
    head_data['User-Agent'] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36X-Requested-With: XMLHttpRequest'
    form_data = {}
    form_data['i'] = content
    form_data['doctype'] = 'json'
    data = parse.urlencode(form_data).encode('utf-8')
    req = request.Request(req_url, data, head_data)
    response = request.urlopen(req)
    html = response.read().decode('utf-8')
    translate_results = json.loads(html)
    translate_results = translate_results['translateResult'][0][0]['tgt']
    print(translate_results)
 
def main():
    while True:
        content = "Christine Jacoba Aaftink"
        if content == 'quit':
             break
        else:
            fanyi(content)
 
if __name__ == '__main__':
    main()
# Out:
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# 克里斯汀Jacoba Aaftink
# ...

# %%
import requests
import json

class fanyi():
 
    def __init__(self,query):
        #设置请求的百度词典翻译的url接口
        self.query_url = "https://fanyi.baidu.com/basetrans"
        #设置请求的百度词典翻译的输入字串的语言的url接口
        self.langdetect_url = "https://fanyi.baidu.com/langdetect"
        self.query = query
        self.headers = {"User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Mobile Safari/537.36"}
 
    def langdetect(self):#判断输入的语言
        request = requests.post(self.langdetect_url, data={"query":"self.query"}, headers=self.headers)
        #获取请求的返回json并进行json解码
        r = json.loads(request.content.decode())
        #切片取值
        return r["lan"]
 
    def post_data(self): #利用输入的语言修改请求的data的值
        #设置请求data
        post_data = {"query": self.query,
                     "from": "en",
                     "to": "zh"
                     }
        #设置请求data
        post_data1 = {"query": self.query,
                     "from": "zh",
                     "to": "en"
                     }
        #判断 此处可优化，由于时间原因，未做过多的处理
        if self.langdetect() == "en":
            return post_data
        else:
            return post_data1
 
 
    def request(self):#返回请求结果
        request = requests.post(self.query_url, data=self.post_data(), headers=self.headers)
        r = json.loads(request.content.decode())
        #仅返回一个常用的译文
        return r["trans"][0]["dst"]
        #返回全部译文
        #return r["dict"]["word_means"]
 
    def run(self):
        print(self.request())
 
if __name__ == "__main__":
    #实例化，传入需翻译的字串
    fanyi = fanyi("China")
    fanyi.run()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-b0d633c43797> in <module>
#      51     #实例化，传入需翻译的字串
#      52     fanyi = fanyi("China")
# ---> 53     fanyi.run()
#
# <ipython-input-15-b0d633c43797> in run(self)
#      46
#      47     def run(self):
# ---> 48         print(self.request())
#      49
#      50 if __name__ == "__main__":
#
# <ipython-input-15-b0d633c43797> in request(self)
#      43 #        return r["trans"][0]["dst"]
#      44         #返回全部译文
# ---> 45         return r["dict"]["word_means"]
#      46
#      47     def run(self):
#
# KeyError: 'dict'
