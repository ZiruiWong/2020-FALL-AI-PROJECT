# %%
common_used_numerals_tmp = {'零': 0, '一': 1, '二': 2, '两': 2, '三': 3, '四': 4, '五': 5, '六': 6, '七': 7, '八': 8, '九': 9,
                            '十': 10, '百': 100, '千': 1000, '万': 10000, '亿': 100000000}
common_used_numerals = {}
for key in common_used_numerals_tmp:
    common_used_numerals[key] = common_used_numerals_tmp[key]
 
 
def chinese2digits(uchars_chinese):
    total = 0
    r = 1  # 表示单位：个十百千...
    for i in range(len(uchars_chinese) - 1, -1, -1):
        val = common_used_numerals.get(uchars_chinese[i])
        if val >= 10 and i == 0:  # 应对 十三 十四 十*之类
            if val > r:
                r = val
                total = total + val
            else:
                r = r * val
                # total =total + r * x
        elif val >= 10:
            if val > r:
                r = val
            else:
                r = r * val
        else:
            total = total + r * val
    return total
 
 
num_str_start_symbol = ['一', '二', '两', '三', '四', '五', '六', '七', '八', '九',
                        '十']
more_num_str_symbol = ['零', '一', '二', '两', '三', '四', '五', '六', '七', '八', '九', '十', '百', '千', '万', '亿']
 
def changeChineseNumToArab(oriStr):
    lenStr = len(oriStr);
    aProStr = ''
    if lenStr == 0:
        return aProStr;
 
    hasNumStart = False;
    numberStr = ''
    for idx in range(lenStr):
        if oriStr[idx] in num_str_start_symbol:
            if not hasNumStart:
                hasNumStart = True;
 
            numberStr += oriStr[idx]
        else:
            if hasNumStart:
                if oriStr[idx] in more_num_str_symbol:
                    numberStr += oriStr[idx]
                    continue
                else:
                    numResult = str(chinese2digits(numberStr))
                    numberStr = ''
                    hasNumStart = False;
                    aProStr += numResult
 
            aProStr += oriStr[idx]
            pass
 
    if len(numberStr) > 0:
        resultNum = chinese2digits(numberStr)
        aProStr += str(resultNum)
 
    return aProStr
 
 
testStr = ['两百三十二', '我有两百三十二块钱', '十二个套餐', '一亿零八万零三百二十三', '今天天气真不错',
           '百分之八十 discount rate很高了', '千万不要',
           '这个invoice value值一百万',
           '我的一百件商品have quality',
           '找一找我的收藏夹里，有没有一个眼镜', ]
 
for tstr in testStr:
    print(tstr + ' = ' + changeChineseNumToArab(tstr))
# Out:
# {'零': 0,
#  '一': 1,
#  '二': 2,
#  '两': 2,
#  '三': 3,
#  '四': 4,
#  '五': 5,
#  '六': 6,
#  '七': 7,
#  '八': 8,
#  '九': 9,
#  '十': 10,
#  '百': 100,
#  '千': 1000,
#  '万': 10000,
#  '亿': 100000000}

# %%
common_used_numerals = {'零': 0, '一': 1, '二': 2, '两': 2, '三': 3, '四': 4, '五': 5, '六': 6, '七': 7, '八': 8, '九': 9,
                            '十': 10, '百': 100, '千': 1000, '万': 10000, '亿': 100000000}
 
 
def chinese2digits(uchars_chinese):
    total = 0
    r = 1  # 表示单位：个十百千...
    for i in range(len(uchars_chinese) - 1, -1, -1):
        val = common_used_numerals.get(uchars_chinese[i])
        if val >= 10 and i == 0:  # 应对 十三 十四 十*之类
            if val > r:
                r = val
                total = total + val
            else:
                r = r * val
                # total =total + r * x
        elif val >= 10:
            if val > r:
                r = val
            else:
                r = r * val
        else:
            total = total + r * val
    return total
 
 
num_str_start_symbol = ['一', '二', '两', '三', '四', '五', '六', '七', '八', '九',
                        '十']
more_num_str_symbol = ['零', '一', '二', '两', '三', '四', '五', '六', '七', '八', '九', '十', '百', '千', '万', '亿']
 
def changeChineseNumToArab(oriStr):
    lenStr = len(oriStr);
    aProStr = ''
    if lenStr == 0:
        return aProStr;
 
    hasNumStart = False;
    numberStr = ''
    for idx in range(lenStr):
        if oriStr[idx] in num_str_start_symbol:
            if not hasNumStart:
                hasNumStart = True;
 
            numberStr += oriStr[idx]
        else:
            if hasNumStart:
                if oriStr[idx] in more_num_str_symbol:
                    numberStr += oriStr[idx]
                    continue
                else:
                    numResult = str(chinese2digits(numberStr))
                    numberStr = ''
                    hasNumStart = False;
                    aProStr += numResult
 
            aProStr += oriStr[idx]
            pass
 
    if len(numberStr) > 0:
        resultNum = chinese2digits(numberStr)
        aProStr += str(resultNum)
 
    return aProStr
 
 
testStr = ['两百三十二', '我有两百三十二块钱', '十二个套餐', '一亿零八万零三百二十三', '今天天气真不错',
           '百分之八十 discount rate很高了', '千万不要',
           '这个invoice value值一百万',
           '我的一百件商品have quality',
           '找一找我的收藏夹里，有没有一个眼镜', ]
 
for tstr in testStr:
    print(tstr + ' = ' + changeChineseNumToArab(tstr))
# Out:
# 两百三十二 = 232
# 我有两百三十二块钱 = 我有232块钱
# 十二个套餐 = 12个套餐
# 一亿零八万零三百二十三 = 100080323
# 今天天气真不错 = 今天天气真不错
# 百分之八十 discount rate很高了 = 百分之80 discount rate很高了
# 千万不要 = 千万不要
# 这个invoice value值一百万 = 这个invoice value值1000000
# 我的一百件商品have quality = 我的100件商品have quality
# 找一找我的收藏夹里，有没有一个眼镜 = 找1找我的收藏夹里，有没有1个眼镜

# %%
def chinese2digits(uchars_chinese):
    common_used_numerals = {'零': 0, '一': 1, '二': 2, '两': 2, '三': 3, '四': 4, '五': 5, '六': 6, '七': 7, '八': 8, '九': 9,
                            '十': 10, '百': 100, '千': 1000, '万': 10000, '亿': 100000000}
    total = 0
    r = 1  # 表示单位：个十百千...
    for i in range(len(uchars_chinese) - 1, -1, -1):
        val = common_used_numerals.get(uchars_chinese[i])
        if val >= 10 and i == 0:  # 应对 十三 十四 十*之类
            if val > r:
                r = val
                total = total + val
            else:
                r = r * val
                # total =total + r * x
        elif val >= 10:
            if val > r:
                r = val
            else:
                r = r * val
        else:
            total = total + r * val
    return total
 
def changeChineseNumToArab(oriStr):
    num_str_start_symbol = ['一', '二', '两', '三', '四', '五', '六', '七', '八', '九',
                        '十']
    more_num_str_symbol = ['零', '一', '二', '两', '三', '四', '五', '六', '七', '八', '九', '十', '百', '千', '万', '亿']
    lenStr = len(oriStr);
    aProStr = ''
    if lenStr == 0:
        return aProStr;
 
    hasNumStart = False;
    numberStr = ''
    for idx in range(lenStr):
        if oriStr[idx] in num_str_start_symbol:
            if not hasNumStart:
                hasNumStart = True;
 
            numberStr += oriStr[idx]
        else:
            if hasNumStart:
                if oriStr[idx] in more_num_str_symbol:
                    numberStr += oriStr[idx]
                    continue
                else:
                    numResult = str(chinese2digits(numberStr))
                    numberStr = ''
                    hasNumStart = False;
                    aProStr += numResult
 
            aProStr += oriStr[idx]
            pass
 
    if len(numberStr) > 0:
        resultNum = chinese2digits(numberStr)
        aProStr += str(resultNum)
 
    return aProStr
 
 
testStr = ['两百三十二', '我有两百三十二块钱', '十二个套餐', '一亿零八万零三百二十三', '今天天气真不错',
           '百分之八十 discount rate很高了', '千万不要',
           '这个invoice value值一百万',
           '我的一百件商品have quality',
           '找一找我的收藏夹里，有没有一个眼镜', ]
 
for tstr in testStr:
    print(tstr + ' = ' + changeChineseNumToArab(tstr))
# Out:
# 两百三十二 = 232
# 我有两百三十二块钱 = 我有232块钱
# 十二个套餐 = 12个套餐
# 一亿零八万零三百二十三 = 100080323
# 今天天气真不错 = 今天天气真不错
# 百分之八十 discount rate很高了 = 百分之80 discount rate很高了
# 千万不要 = 千万不要
# 这个invoice value值一百万 = 这个invoice value值1000000
# 我的一百件商品have quality = 我的100件商品have quality
# 找一找我的收藏夹里，有没有一个眼镜 = 找1找我的收藏夹里，有没有1个眼镜

# %%
def chinese2digits(uchars_chinese):
    common_used_numerals = {'零': 0, '一': 1, '二': 2, '两': 2, '三': 3, '四': 4, '五': 5, '六': 6, '七': 7, '八': 8, '九': 9,
                            '十': 10, '百': 100, '千': 1000, '万': 10000, '亿': 100000000}
    total = 0
    r = 1  # 表示单位：个十百千...
    for i in range(len(uchars_chinese) - 1, -1, -1):
        val = common_used_numerals.get(uchars_chinese[i])
        if val >= 10 and i == 0:  # 应对 十三 十四 十*之类
            if val > r:
                r = val
                total = total + val
            else:
                r = r * val
                # total =total + r * x
        elif val >= 10:
            if val > r:
                r = val
            else:
                r = r * val
        else:
            total = total + r * val
    return total
 
def changeChineseNumToArab(oriStr):
    num_str_start_symbol = ['一', '二', '两', '三', '四', '五', '六', '七', '八', '九',
                        '十']
    more_num_str_symbol = ['零', '一', '二', '两', '三', '四', '五', '六', '七', '八', '九', '十', '百', '千', '万', '亿']
    lenStr = len(oriStr);
    aProStr = ''
    if lenStr == 0:
        return aProStr;
 
    hasNumStart = False;
    numberStr = ''
    for idx in range(lenStr):
        if oriStr[idx] in num_str_start_symbol:
            if not hasNumStart:
                hasNumStart = True;
 
            numberStr += oriStr[idx]
        else:
            if hasNumStart:
                if oriStr[idx] in more_num_str_symbol:
                    numberStr += oriStr[idx]
                    continue
                else:
                    numResult = str(chinese2digits(numberStr))
                    numberStr = ''
                    hasNumStart = False;
                    aProStr += numResult
 
            aProStr += oriStr[idx]
            pass
 
    if len(numberStr) > 0:
        resultNum = chinese2digits(numberStr)
        aProStr += str(resultNum)
 
    return aProStr
 
 
testStr = ['两百三十二', '我有两百三十二块钱', '十二个套餐', '一亿零八万零三百二十三', '今天天气真不错',
           '百分之八十 discount rate很高了', '千万不要',
           '这个invoice value值一百万',
           '我的一百件商品have quality',
           '找一找我的收藏夹里，有没有一个眼镜', ]
 
for tstr in testStr:
    print(tstr + ' = ' + changeChineseNumToArab(tstr))
# Out:
# 两百三十二 = 232
# 我有两百三十二块钱 = 我有232块钱
# 十二个套餐 = 12个套餐
# 一亿零八万零三百二十三 = 100080323
# 今天天气真不错 = 今天天气真不错
# 百分之八十 discount rate很高了 = 百分之80 discount rate很高了
# 千万不要 = 千万不要
# 这个invoice value值一百万 = 这个invoice value值1000000
# 我的一百件商品have quality = 我的100件商品have quality
# 找一找我的收藏夹里，有没有一个眼镜 = 找1找我的收藏夹里，有没有1个眼镜

# %%
stopwords = [line.strip() for line in open('./dic/stopword.txt', 'r').readlines()]
stopwords
# Out:
# [b'--',
#  b'?',
#  b'\xe2\x80\x9c',
#  b'\xe2\x80\x9d',
#  b'\xe3\x80\x8b',
#  b'\xef\xbc\x8d\xef\xbc\x8d',
#  b'able',
#  b'about',
#  b'above',
#  b'according',
#  b'accordingly',
#  b'across',
#  b'actually',
#  b'after',
#  b'afterwards',
#  b'again',
#  b'against',
#  b"ain't",
#  b'all',
#  b'allow',
#  b'allows',
#  b'almost',
#  b'alone',
#  b'along',
#  b'already',
#  b'also',
#  b'although',
#  b'always',
#  b'am',
#  b'among',
#  b'amongst',
#  b'an',
#  b'and',
#  b'another',
#  b'any',
#  b'anybody',
#  b'anyhow',
#  b'anyone',
#  b'anything',
#  b'anyway',
#  b'anyways',
#  b'anywhere',
#  b'apart',
#  b'appear',
#  b'appreciate',
#  b'appropriate',
#  b'are',
#  b"aren't",
#  b'around',
#  b'as',
#  b"a's",
#  b'aside',
#  b'ask',
#  b'asking',
#  b'associated',
#  b'at',
#  b'available',
#  b'away',
#  b'awfully',
#  b'be',
#  b'became',
#  b'because',
#  b'become',
#  b'becomes',
#  b'becoming',
#  b'been',
#  b'before',
#  b'beforehand',
#  b'behind',
#  b'being',
#  b'believe',
#  b'below',
#  b'beside',
#  b'besides',
#  b'best',
#  b'better',
#  b'between',
#  b'beyond',
#  b'both',
#  b'brief',
#  b'but',
#  b'by',
#  b'came',
#  b'can',
#  b'cannot',
#  b'cant',
#  b"can't",
#  b'cause',
#  b'causes',
#  b'certain',
#  b'certainly',
#  b'changes',
#  b'clearly',
#  b"c'mon",
#  b'co',
#  b'com',
#  b'come',
#  b'comes',
#  b'concerning',
#  b'consequently',
#  b'consider',
#  b'considering',
#  b'contain',
#  b'containing',
#  b'contains',
#  b'corresponding',
#  b'could',
#  b"couldn't",
#  b'course',
#  b"c's",
#  b'currently',
#  b'definitely',
#  b'described',
#  b'despite',
#  b'did',
#  b"didn't",
#  b'different',
#  b'do',
#  b'does',
#  b"doesn't",
#  b'doing',
#  b'done',
#  b"don't",
#  b'down',
#  b'downwards',
#  b'during',
#  b'each',
#  b'edu',
#  b'eg',
#  b'eight',
#  b'either',
#  b'else',
#  b'elsewhere',
#  b'enough',
#  b'entirely',
#  b'especially',
#  b'et',
#  b'etc',
#  b'even',
#  b'ever',
#  b'every',
#  b'everybody',
#  b'everyone',
#  b'everything',
#  b'everywhere',
#  b'ex',
#  b'exactly',
#  b'example',
#  b'except',
#  b'far',
#  b'few',
#  b'fifth',
#  b'first',
#  b'five',
#  b'followed',
#  b'following',
#  b'follows',
#  b'for',
#  b'former',
#  b'formerly',
#  b'forth',
#  b'four',
#  b'from',
#  b'further',
#  b'furthermore',
#  b'get',
#  b'gets',
#  b'getting',
#  b'given',
#  b'gives',
#  b'go',
#  b'goes',
#  b'going',
#  b'gone',
#  b'got',
#  b'gotten',
#  b'greetings',
#  b'had',
#  b"hadn't",
#  b'happens',
#  b'hardly',
#  b'has',
#  b"hasn't",
#  b'have',
#  b"haven't",
#  b'having',
#  b'he',
#  b'hello',
#  b'help',
#  b'hence',
#  b'her',
#  b'here',
#  b'hereafter',
#  b'hereby',
#  b'herein',
#  b"here's",
#  b'hereupon',
#  b'hers',
#  b'herself',
#  b"he's",
#  b'hi',
#  b'him',
#  b'himself',
#  b'his',
#  b'hither',
#  b'hopefully',
#  b'how',
#  b'howbeit',
#  b'however',
#  b"i'd",
#  b'ie',
#  b'if',
#  b'ignored',
#  b"i'll",
#  b"i'm",
#  b'immediate',
#  b'in',
#  b'inasmuch',
#  b'inc',
#  b'indeed',
#  b'indicate',
#  b'indicated',
#  b'indicates',
#  b'inner',
#  b'insofar',
#  b'instead',
#  b'into',
#  b'inward',
#  b'is',
#  b"isn't",
#  b'it',
#  b"it'd",
#  b"it'll",
#  b'its',
#  b"it's",
#  b'itself',
#  b"i've",
#  b'just',
#  b'keep',
#  b'keeps',
#  b'kept',
#  b'know',
#  b'known',
#  b'knows',
#  b'last',
#  b'lately',
#  b'later',
#  b'latter',
#  b'latterly',
#  b'least',
#  b'less',
#  b'lest',
#  b'let',
#  b"let's",
#  b'like',
#  b'liked',
#  b'likely',
#  b'little',
#  b'look',
#  b'looking',
#  b'looks',
#  b'ltd',
#  b'mainly',
#  b'many',
#  b'may',
#  b'maybe',
#  b'me',
#  b'mean',
#  b'meanwhile',
#  b'merely',
#  b'might',
#  b'more',
#  b'moreover',
#  b'most',
#  b'mostly',
#  b'much',
#  b'must',
#  b'my',
#  b'myself',
#  b'name',
#  b'namely',
#  b'nd',
#  b'near',
#  b'nearly',
#  b'necessary',
#  b'need',
#  b'needs',
#  b'neither',
#  b'never',
#  b'nevertheless',
#  b'new',
#  b'next',
#  b'nine',
#  b'no',
#  b'nobody',
#  b'non',
#  b'none',
#  b'noone',
#  b'nor',
#  b'normally',
#  b'not',
#  b'nothing',
#  b'novel',
#  b'now',
#  b'nowhere',
#  b'obviously',
#  b'of',
#  b'off',
#  b'often',
#  b'oh',
#  b'ok',
#  b'okay',
#  b'old',
#  b'on',
#  b'once',
#  b'one',
#  b'ones',
#  b'only',
#  b'onto',
#  b'or',
#  b'other',
#  b'others',
#  b'otherwise',
#  b'ought',
#  b'our',
#  b'ours',
#  b'ourselves',
#  b'out',
#  b'outside',
#  b'over',
#  b'overall',
#  b'own',
#  b'particular',
#  b'particularly',
#  b'per',
#  b'perhaps',
#  b'placed',
#  b'please',
#  b'plus',
#  b'possible',
#  b'presumably',
#  b'probably',
#  b'provides',
#  b'que',
#  b'quite',
#  b'qv',
#  b'rather',
#  b'rd',
#  b're',
#  b'really',
#  b'reasonably',
#  b'regarding',
#  b'regardless',
#  b'regards',
#  b'relatively',
#  b'respectively',
#  b'right',
#  b'said',
#  b'same',
#  b'saw',
#  b'say',
#  b'saying',
#  b'says',
#  b'second',
#  b'secondly',
#  b'see',
#  b'seeing',
#  b'seem',
#  b'seemed',
#  b'seeming',
#  b'seems',
#  b'seen',
#  b'self',
#  b'selves',
#  b'sensible',
#  b'sent',
#  b'serious',
#  b'seriously',
#  b'seven',
#  b'several',
#  b'shall',
#  b'she',
#  b'should',
#  b"shouldn't",
#  b'since',
#  b'six',
#  b'so',
#  b'some',
#  b'somebody',
#  b'somehow',
#  b'someone',
#  b'something',
#  b'sometime',
#  b'sometimes',
#  b'somewhat',
#  b'somewhere',
#  b'soon',
#  b'sorry',
#  b'specified',
#  b'specify',
#  b'specifying',
#  b'still',
#  b'sub',
#  b'such',
#  b'sup',
#  b'sure',
#  b'take',
#  b'taken',
#  b'tell',
#  b'tends',
#  b'th',
#  b'than',
#  b'thank',
#  b'thanks',
#  b'thanx',
#  b'that',
#  b'thats',
#  b"that's",
#  b'the',
#  b'their',
#  b'theirs',
#  b'them',
#  b'themselves',
#  b'then',
#  b'thence',
#  b'there',
#  b'thereafter',
#  b'thereby',
#  b'therefore',
#  b'therein',
#  b'theres',
#  b"there's",
#  b'thereupon',
#  b'these',
#  b'they',
#  b"they'd",
#  b"they'll",
#  b"they're",
#  b"they've",
#  b'think',
#  b'third',
#  b'this',
#  b'thorough',
#  b'thoroughly',
#  b'those',
#  b'though',
#  b'three',
#  b'through',
#  b'throughout',
#  b'thru',
#  b'thus',
#  b'to',
#  b'together',
#  b'too',
#  b'took',
#  b'toward',
#  b'towards',
#  b'tried',
#  b'tries',
#  b'truly',
#  b'try',
#  b'trying',
#  b"t's",
#  b'twice',
#  b'two',
#  b'un',
#  b'under',
#  b'unfortunately',
#  b'unless',
#  b'unlikely',
#  b'until',
#  b'unto',
#  b'up',
#  b'upon',
#  b'us',
#  b'use',
#  b'used',
#  b'useful',
#  b'uses',
#  b'using',
#  b'usually',
#  b'value',
#  b'various',
#  b'very',
#  b'via',
#  b'viz',
#  b'vs',
#  b'want',
#  b'wants',
#  b'was',
#  b"wasn't",
#  b'way',
#  b'we',
#  b"we'd",
#  b'welcome',
#  b'well',
#  b"we'll",
#  b'went',
#  b'were',
#  b"we're",
#  b"weren't",
#  b"we've",
#  b'what',
#  b'whatever',
#  b"what's",
#  b'when',
#  b'whence',
#  b'whenever',
#  b'where',
#  b'whereafter',
#  b'whereas',
#  b'whereby',
#  b'wherein',
#  b"where's",
#  b'whereupon',
#  b'wherever',
#  b'whether',
#  b'which',
#  b'while',
#  b'whither',
#  b'who',
#  b'whoever',
#  b'whole',
#  b'whom',
#  b"who's",
#  b'whose',
#  b'why',
#  b'will',
#  b'willing',
#  b'wish',
#  b'with',
#  b'within',
#  b'without',
#  b'wonder',
#  b"won't",
#  b'would',
#  b"wouldn't",
#  b'yes',
#  b'yet',
#  b'you',
#  b"you'd",
#  b"you'll",
#  b'your',
#  b"you're",
#  b'yours',
#  b'yourself',
#  b'yourselves',
#  b"you've",
#  b'zero',
#  b'zt',
#  b'ZT',
#  b'zz',
#  b'ZZ',
#  b'\xe4\xb8\x80',
#  b'\xe4\xb8\x80\xe4\xb8\x8b',
#  b'\xe4\xb8\x80\xe4\xba\x9b',
#  b'\xe4\xb8\x80\xe5\x88\x87',
#  b'\xe4\xb8\x80\xe5\x88\x99',
#  b'\xe4\xb8\x80\xe5\xa4\xa9',
#  b'\xe4\xb8\x80\xe5\xae\x9a',
#  b'\xe4\xb8\x80\xe6\x96\xb9\xe9\x9d\xa2',
#  b'\xe4\xb8\x80\xe6\x97\xa6',
#  b'\xe4\xb8\x80\xe6\x97\xb6',
#  b'\xe4\xb8\x80\xe6\x9d\xa5',
#  b'\xe4\xb8\x80\xe6\xa0\xb7',
#  b'\xe4\xb8\x80\xe6\xac\xa1',
#  b'\xe4\xb8\x80\xe7\x89\x87',
#  b'\xe4\xb8\x80\xe7\x9b\xb4',
#  b'\xe4\xb8\x80\xe8\x87\xb4',
#  b'\xe4\xb8\x80\xe8\x88\xac',
#  b'\xe4\xb8\x80\xe8\xb5\xb7',
#  b'\xe4\xb8\x80\xe8\xbe\xb9',
#  b'\xe4\xb8\x80\xe9\x9d\xa2',
#  b'\xe4\xb8\x87\xe4\xb8\x80',
#  b'\xe4\xb8\x8a\xe4\xb8\x8b',
#  b'\xe4\xb8\x8a\xe5\x8d\x87',
#  b'\xe4\xb8\x8a\xe5\x8e\xbb',
#  b'\xe4\xb8\x8a\xe6\x9d\xa5',
#  b'\xe4\xb8\x8a\xe8\xbf\xb0',
#  b'\xe4\xb8\x8a\xe9\x9d\xa2',
#  b'\xe4\xb8\x8b\xe5\x88\x97',
#  b'\xe4\xb8\x8b\xe5\x8e\xbb',
#  b'\xe4\xb8\x8b\xe6\x9d\xa5',
#  b'\xe4\xb8\x8b\xe9\x9d\xa2',
#  b'\xe4\xb8\x8d\xe4\xb8\x80',
#  b'\xe4\xb8\x8d\xe4\xb9\x85',
#  b'\xe4\xb8\x8d\xe4\xbb\x85',
#  b'\xe4\xb8\x8d\xe4\xbc\x9a',
#  b'\xe4\xb8\x8d\xe4\xbd\x86',
#  b'\xe4\xb8\x8d\xe5\x85\x89',
#  b'\xe4\xb8\x8d\xe5\x8d\x95',
#  b'\xe4\xb8\x8d\xe5\x8f\x98',
#  b'\xe4\xb8\x8d\xe5\x8f\xaa',
#  b'\xe4\xb8\x8d\xe5\x8f\xaf',
#  b'\xe4\xb8\x8d\xe5\x90\x8c',
#  b'\xe4\xb8\x8d\xe5\xa4\x9f',
#  b'\xe4\xb8\x8d\xe5\xa6\x82',
#  b'\xe4\xb8\x8d\xe5\xbe\x97',
#  b'\xe4\xb8\x8d\xe6\x80\x95',
#  b'\xe4\xb8\x8d\xe6\x83\x9f',
#  b'\xe4\xb8\x8d\xe6\x88\x90',
#  b'\xe4\xb8\x8d\xe6\x8b\x98',
#  b'\xe4\xb8\x8d\xe6\x95\xa2',
#  b'\xe4\xb8\x8d\xe6\x96\xad',
#  b'\xe4\xb8\x8d\xe6\x98\xaf',
#  b'\xe4\xb8\x8d\xe6\xaf\x94',
#  b'\xe4\xb8\x8d\xe7\x84\xb6',
#  b'\xe4\xb8\x8d\xe7\x89\xb9',
#  b'\xe4\xb8\x8d\xe7\x8b\xac',
#  b'\xe4\xb8\x8d\xe7\xae\xa1',
#  b'\xe4\xb8\x8d\xe8\x83\xbd',
#  b'\xe4\xb8\x8d\xe8\xa6\x81',
#  b'\xe4\xb8\x8d\xe8\xae\xba',
#  b'\xe4\xb8\x8d\xe8\xb6\xb3',
#  b'\xe4\xb8\x8d\xe8\xbf\x87',
#  b'\xe4\xb8\x8d\xe9\x97\xae',
#  b'\xe4\xb8\x8e',
#  b'\xe4\xb8\x8e\xe5\x85\xb6',
#  b'\xe4\xb8\x8e\xe5\x90\xa6',
#  b'\xe4\xb8\x8e\xe6\xad\xa4\xe5\x90\x8c\xe6\x97\xb6',
#  b'\xe4\xb8\x93\xe9\x97\xa8',
#  b'\xe4\xb8\x94',
#  b'\xe4\xb8\xa4\xe8\x80\x85',
#  b'\xe4\xb8\xa5\xe6\xa0\xbc',
#  b'\xe4\xb8\xa5\xe9\x87\x8d',
#  b'\xe4\xb8\xaa',
#  b'\xe4\xb8\xaa\xe4\xba\xba',
#  b'\xe4\xb8\xaa\xe5\x88\xab',
#  b'\xe4\xb8\xad\xe5\xb0\x8f',
#  b'\xe4\xb8\xad\xe9\x97\xb4',
#  b'\xe4\xb8\xb0\xe5\xaf\x8c',
#  b'\xe4\xb8\xb4',
#  b'\xe4\xb8\xba',
#  b'\xe4\xb8\xba\xe4\xb8\xbb',
#  b'\xe4\xb8\xba\xe4\xba\x86',
#  b'\xe4\xb8\xba\xe4\xbb\x80\xe4\xb9\x88',
#  b'\xe4\xb8\xba\xe4\xbb\x80\xe9\xba\xbd',
#  b'\xe4\xb8\xba\xe4\xbd\x95',
#  b'\xe4\xb8\xba\xe7\x9d\x80',
#  b'\xe4\xb8\xbb\xe5\xbc\xa0',
#  b'\xe4\xb8\xbb\xe8\xa6\x81',
#  b'\xe4\xb8\xbe\xe8\xa1\x8c',
#  b'\xe4\xb9\x83',
#  b'\xe4\xb9\x83\xe8\x87\xb3',
#  b'\xe4\xb9\x88',
#  b'\xe4\xb9\x8b',
#  b'\xe4\xb9\x8b\xe4\xb8\x80',
#  b'\xe4\xb9\x8b\xe5\x89\x8d',
#  b'\xe4\xb9\x8b\xe5\x90\x8e',
#  b'\xe4\xb9\x8b\xe5\xbe\x8c',
#  b'\xe4\xb9\x8b\xe6\x89\x80\xe4\xbb\xa5',
#  b'\xe4\xb9\x8b\xe7\xb1\xbb',
#  b'\xe4\xb9\x8c\xe4\xb9\x8e',
#  b'\xe4\xb9\x8e',
#  b'\xe4\xb9\x98',
#  b'\xe4\xb9\x9f',
#  b'\xe4\xb9\x9f\xe5\xa5\xbd',
#  b'\xe4\xb9\x9f\xe6\x98\xaf',
#  b'\xe4\xb9\x9f\xe7\xbd\xa2',
#  b'\xe4\xba\x86',
#  b'\xe4\xba\x86\xe8\xa7\xa3',
#  b'\xe4\xba\x89\xe5\x8f\x96',
#  b'\xe4\xba\x8e',
#  b'\xe4\xba\x8e\xe6\x98\xaf',
#  b'\xe4\xba\x8e\xe6\x98\xaf\xe4\xb9\x8e',
#  b'\xe4\xba\x91\xe4\xba\x91',
#  b'\xe4\xba\x92\xe7\x9b\xb8',
#  b'\xe4\xba\xa7\xe7\x94\x9f',
#  b'\xe4\xba\xba\xe4\xbb\xac',
#  b'\xe4\xba\xba\xe5\xae\xb6',
#  b'\xe4\xbb\x80\xe4\xb9\x88',
#  b'\xe4\xbb\x80\xe4\xb9\x88\xe6\xa0\xb7',
#  b'\xe4\xbb\x80\xe9\xba\xbd',
#  b'\xe4\xbb\x8a\xe5\x90\x8e',
#  b'\xe4\xbb\x8a\xe5\xa4\xa9',
#  b'\xe4\xbb\x8a\xe5\xb9\xb4',
#  b'\xe4\xbb\x8a\xe5\xbe\x8c',
#  b'\xe4\xbb\x8d\xe7\x84\xb6',
#  b'\xe4\xbb\x8e',
#  b'\xe4\xbb\x8e\xe4\xba\x8b',
#  b'\xe4\xbb\x8e\xe8\x80\x8c',
#  b'\xe4\xbb\x96',
#  b'\xe4\xbb\x96\xe4\xba\xba',
#  b'\xe4\xbb\x96\xe4\xbb\xac',
#  b'\xe4\xbb\x96\xe7\x9a\x84',
#  b'\xe4\xbb\xa3\xe6\x9b\xbf',
#  b'\xe4\xbb\xa5',
#  b'\xe4\xbb\xa5\xe4\xb8\x8a',
#  b'\xe4\xbb\xa5\xe4\xb8\x8b',
#  b'\xe4\xbb\xa5\xe4\xb8\xba',
#  b'\xe4\xbb\xa5\xe4\xbe\xbf',
#  b'\xe4\xbb\xa5\xe5\x85\x8d',
#  b'\xe4\xbb\xa5\xe5\x89\x8d',
#  b'\xe4\xbb\xa5\xe5\x8f\x8a',
#  b'\xe4\xbb\xa5\xe5\x90\x8e',
#  b'\xe4\xbb\xa5\xe5\xa4\x96',
#  b'\xe4\xbb\xa5\xe5\xbe\x8c',
#  b'\xe4\xbb\xa5\xe6\x9d\xa5',
#  b'\xe4\xbb\xa5\xe8\x87\xb3',
#  b'\xe4\xbb\xa5\xe8\x87\xb3\xe4\xba\x8e',
#  b'\xe4\xbb\xa5\xe8\x87\xb4',
#  b'\xe4\xbb\xac',
#  b'\xe4\xbb\xbb',
#  b'\xe4\xbb\xbb\xe4\xbd\x95',
#  b'\xe4\xbb\xbb\xe5\x87\xad',
#  b'\xe4\xbb\xbb\xe5\x8a\xa1',
#  b'\xe4\xbc\x81\xe5\x9b\xbe',
#  b'\xe4\xbc\x9f\xe5\xa4\xa7',
#  b'\xe4\xbc\xbc\xe4\xb9\x8e',
#  b'\xe4\xbc\xbc\xe7\x9a\x84',
#  b'\xe4\xbd\x86',
#  b'\xe4\xbd\x86\xe6\x98\xaf',
#  b'\xe4\xbd\x95',
#  b'\xe4\xbd\x95\xe5\x86\xb5',
#  b'\xe4\xbd\x95\xe5\xa4\x84',
#  b'\xe4\xbd\x95\xe6\x97\xb6',
#  b'\xe4\xbd\x9c\xe4\xb8\xba',
#  b'\xe4\xbd\xa0',
#  b'\xe4\xbd\xa0\xe4\xbb\xac',
#  b'\xe4\xbd\xa0\xe7\x9a\x84',
#  b'\xe4\xbd\xbf\xe5\xbe\x97',
#  b'\xe4\xbd\xbf\xe7\x94\xa8',
#  b'\xe4\xbe\x8b\xe5\xa6\x82',
#  b'\xe4\xbe\x9d',
#  b'\xe4\xbe\x9d\xe7\x85\xa7',
#  b'\xe4\xbe\x9d\xe9\x9d\xa0',
#  b'\xe4\xbf\x83\xe8\xbf\x9b',
#  b'\xe4\xbf\x9d\xe6\x8c\x81',
#  b'\xe4\xbf\xba',
#  b'\xe4\xbf\xba\xe4\xbb\xac',
#  b'\xe5\x80\x98',
#  b'\xe5\x80\x98\xe4\xbd\xbf',
#  b'\xe5\x80\x98\xe6\x88\x96',
#  b'\xe5\x80\x98\xe7\x84\xb6',
#  b'\xe5\x80\x98\xe8\x8b\xa5',
#  b'\xe5\x81\x87\xe4\xbd\xbf',
#  b'\xe5\x81\x87\xe5\xa6\x82',
#  b'\xe5\x81\x87\xe8\x8b\xa5',
#  b'\xe5\x81\x9a\xe5\x88\xb0',
#  b'\xe5\x83\x8f',
#  b'\xe5\x85\x81\xe8\xae\xb8',
#  b'\xe5\x85\x85\xe5\x88\x86',
#  b'\xe5\x85\x88\xe5\x90\x8e',
#  b'\xe5\x85\x88\xe5\xbe\x8c',
#  b'\xe5\x85\x88\xe7\x94\x9f',
#  b'\xe5\x85\xa8\xe9\x83\xa8',
#  b'\xe5\x85\xa8\xe9\x9d\xa2',
#  b'\xe5\x85\xae',
#  b'\xe5\x85\xb1\xe5\x90\x8c',
#  b'\xe5\x85\xb3\xe4\xba\x8e',
#  b'\xe5\x85\xb6',
#  b'\xe5\x85\xb6\xe4\xb8\x80',
#  b'\xe5\x85\xb6\xe4\xb8\xad',
#  b'\xe5\x85\xb6\xe4\xba\x8c',
#  b'\xe5\x85\xb6\xe4\xbb\x96',
#  b'\xe5\x85\xb6\xe4\xbd\x99',
#  b'\xe5\x85\xb6\xe5\xae\x83',
#  b'\xe5\x85\xb6\xe5\xae\x9e',
#  b'\xe5\x85\xb6\xe6\xac\xa1',
#  b'\xe5\x85\xb7\xe4\xbd\x93',
#  b'\xe5\x85\xb7\xe4\xbd\x93\xe5\x9c\xb0\xe8\xaf\xb4',
#  b'\xe5\x85\xb7\xe4\xbd\x93\xe8\xaf\xb4\xe6\x9d\xa5',
#  b'\xe5\x85\xb7\xe6\x9c\x89',
#  b'\xe5\x86\x8d\xe8\x80\x85',
#  b'\xe5\x86\x8d\xe8\xaf\xb4',
#  b'\xe5\x86\x92',
#  b'\xe5\x86\xb2',
#  b'\xe5\x86\xb3\xe5\xae\x9a',
#  b'\xe5\x86\xb5\xe4\xb8\x94',
#  b'\xe5\x87\x86\xe5\xa4\x87',
#  b'\xe5\x87\xa0',
#  b'\xe5\x87\xa0\xe4\xb9\x8e',
#  b'\xe5\x87\xa0\xe6\x97\xb6',
#  b'\xe5\x87\xad',
#  b'\xe5\x87\xad\xe5\x80\x9f',
#  b'\xe5\x87\xba\xe5\x8e\xbb',
#  b'\xe5\x87\xba\xe6\x9d\xa5',
#  b'\xe5\x87\xba\xe7\x8e\xb0',
#  b'\xe5\x88\x86\xe5\x88\xab',
#  b'\xe5\x88\x99',
#  b'\xe5\x88\xab',
#  b'\xe5\x88\xab\xe7\x9a\x84',
#  b'\xe5\x88\xab\xe8\xaf\xb4',
#  b'\xe5\x88\xb0',
#  b'\xe5\x89\x8d\xe5\x90\x8e',
#  b'\xe5\x89\x8d\xe8\x80\x85',
#  b'\xe5\x89\x8d\xe8\xbf\x9b',
#  b'\xe5\x89\x8d\xe9\x9d\xa2',
#  b'\xe5\x8a\xa0\xe4\xb9\x8b',
#  b'\xe5\x8a\xa0\xe4\xbb\xa5',
#  b'\xe5\x8a\xa0\xe5\x85\xa5',
#  b'\xe5\x8a\xa0\xe5\xbc\xba',
#  b'\xe5\x8d\x81\xe5\x88\x86',
#  b'\xe5\x8d\xb3',
#  b'\xe5\x8d\xb3\xe4\xbb\xa4',
#  b'\xe5\x8d\xb3\xe4\xbd\xbf',
#  b'\xe5\x8d\xb3\xe4\xbe\xbf',
#  b'\xe5\x8d\xb3\xe6\x88\x96',
#  b'\xe5\x8d\xb3\xe8\x8b\xa5',
#  b'\xe5\x8d\xb4\xe4\xb8\x8d',
#  b'\xe5\x8e\x9f\xe6\x9d\xa5',
#  b'\xe5\x8f\x88',
#  b'\xe5\x8f\x8a',
#  b'\xe5\x8f\x8a\xe5\x85\xb6',
#  b'\xe5\x8f\x8a\xe6\x97\xb6',
#  b'\xe5\x8f\x8a\xe8\x87\xb3',
#  b'\xe5\x8f\x8c\xe6\x96\xb9',
#  b'\xe5\x8f\x8d\xe4\xb9\x8b',
#  b'\xe5\x8f\x8d\xe5\xba\x94',
#  b'\xe5\x8f\x8d\xe6\x98\xa0',
#  b'\xe5\x8f\x8d\xe8\xbf\x87\xe6\x9d\xa5',
#  b'\xe5\x8f\x8d\xe8\xbf\x87\xe6\x9d\xa5\xe8\xaf\xb4',
#  b'\xe5\x8f\x96\xe5\xbe\x97',
#  b'\xe5\x8f\x97\xe5\x88\xb0',
#  b'\xe5\x8f\x98\xe6\x88\x90',
#  b'\xe5\x8f\xa6',
#  b'\xe5\x8f\xa6\xe4\xb8\x80\xe6\x96\xb9\xe9\x9d\xa2',
#  b'\xe5\x8f\xa6\xe5\xa4\x96',
#  b'\xe5\x8f\xaa\xe6\x98\xaf',
#  b'\xe5\x8f\xaa\xe6\x9c\x89',
#  b'\xe5\x8f\xaa\xe8\xa6\x81',
#  b'\xe5\x8f\xaa\xe9\x99\x90',
#  b'\xe5\x8f\xab',
#  b'\xe5\x8f\xab\xe5\x81\x9a',
#  b'\xe5\x8f\xac\xe5\xbc\x80',
#  b'\xe5\x8f\xae\xe5\x92\x9a',
#  b'\xe5\x8f\xaf',
#  b'\xe5\x8f\xaf\xe4\xbb\xa5',
#  b'\xe5\x8f\xaf\xe6\x98\xaf',
#  b'\xe5\x8f\xaf\xe8\x83\xbd',
#  b'\xe5\x8f\xaf\xe8\xa7\x81',
#  b'\xe5\x90\x84',
#  b'\xe5\x90\x84\xe4\xb8\xaa',
#  b'\xe5\x90\x84\xe4\xba\xba',
#  b'\xe5\x90\x84\xe4\xbd\x8d',
#  b'\xe5\x90\x84\xe5\x9c\xb0',
#  b'\xe5\x90\x84\xe7\xa7\x8d',
#  b'\xe5\x90\x84\xe7\xba\xa7',
#  b'\xe5\x90\x84\xe8\x87\xaa',
#  b'\xe5\x90\x88\xe7\x90\x86',
#  b'\xe5\x90\x8c',
#  b'\xe5\x90\x8c\xe4\xb8\x80',
#  b'\xe5\x90\x8c\xe6\x97\xb6',
#  b'\xe5\x90\x8c\xe6\xa0\xb7',
#  b'\xe5\x90\x8e\xe6\x9d\xa5',
#  b'\xe5\x90\x8e\xe9\x9d\xa2',
#  b'\xe5\x90\x91',
#  b'\xe5\x90\x91\xe7\x9d\x80',
#  b'\xe5\x90\x93',
#  b'\xe5\x90\x97',
#  b'\xe5\x90\xa6\xe5\x88\x99',
#  b'\xe5\x90\xa7',
#  b'\xe5\x90\xa7\xe5\x93\x92',
#  b'\xe5\x90\xb1',
#  b'\xe5\x91\x80',
#  b'\xe5\x91\x83',
#  b'\xe5\x91\x95',
#  b'\xe5\x91\x97',
#  b'\xe5\x91\x9c',
#  b'\xe5\x91\x9c\xe5\x91\xbc',
#  b'\xe5\x91\xa2',
#  b'\xe5\x91\xa8\xe5\x9b\xb4',
#  b'\xe5\x91\xb5',
#  b'\xe5\x91\xb8',
#  b'\xe5\x91\xbc\xe5\x93\xa7',
#  b'\xe5\x92\x8b',
#  b'\xe5\x92\x8c',
#  b'\xe5\x92\x9a',
#  b'\xe5\x92\xa6',
#  b'\xe5\x92\xb1',
#  b'\xe5\x92\xb1\xe4\xbb\xac',
#  b'\xe5\x92\xb3',
#  b'\xe5\x93\x87',
#  b'\xe5\x93\x88',
#  b'\xe5\x93\x88\xe5\x93\x88',
#  b'\xe5\x93\x89',
#  b'\xe5\x93\x8e',
#  b'\xe5\x93\x8e\xe5\x91\x80',
#  b'\xe5\x93\x8e\xe5\x93\x9f',
#  b'\xe5\x93\x97',
#  b'\xe5\x93\x9f',
#  b'\xe5\x93\xa6',
#  b'\xe5\x93\xa9',
#  b'\xe5\x93\xaa',
#  b'\xe5\x93\xaa\xe4\xb8\xaa',
#  b'\xe5\x93\xaa\xe4\xba\x9b',
#  b'\xe5\x93\xaa\xe5\x84\xbf',
#  b'\xe5\x93\xaa\xe5\xa4\xa9',
#  b'\xe5\x93\xaa\xe5\xb9\xb4',
#  b'\xe5\x93\xaa\xe6\x80\x95',
#  b'\xe5\x93\xaa\xe6\xa0\xb7',
#  b'\xe5\x93\xaa\xe8\xbe\xb9',
#  b'\xe5\x93\xaa\xe9\x87\x8c',
#  b'\xe5\x93\xbc',
#  b'\xe5\x93\xbc\xe5\x94\xb7',
#  b'\xe5\x94\x89',
#  b'\xe5\x95\x8a',
#  b'\xe5\x95\x90',
#  b'\xe5\x95\xa5',
#  b'\xe5\x95\xa6',
#  b'\xe5\x95\xaa\xe8\xbe\xbe',
#  b'\xe5\x96\x82',
#  b'\xe5\x96\x8f',
#  b'\xe5\x96\x94\xe5\x94\xb7',
#  b'\xe5\x97\xa1\xe5\x97\xa1',
#  b'\xe5\x97\xac',
#  b'\xe5\x97\xaf',
#  b'\xe5\x97\xb3',
#  b'\xe5\x98\x8e',
#  b'\xe5\x98\x8e\xe7\x99\xbb',
#  b'\xe5\x98\x98',
#  b'\xe5\x98\x9b',
#  b'\xe5\x98\xbb',
#  b'\xe5\x98\xbf',
#  b'\xe5\x9b\xa0',
#  b'\xe5\x9b\xa0\xe4\xb8\xba',
#  b'\xe5\x9b\xa0\xe6\xad\xa4',
#  b'\xe5\x9b\xa0\xe8\x80\x8c',
#  b'\xe5\x9b\xba\xe7\x84\xb6',
#  b'\xe5\x9c\xa8',
#  b'\xe5\x9c\xa8\xe4\xb8\x8b',
#  b'\xe5\x9c\xb0',
#  b'\xe5\x9d\x9a\xe5\x86\xb3',
#  b'\xe5\x9d\x9a\xe6\x8c\x81',
#  b'\xe5\x9f\xba\xe6\x9c\xac',
#  b'\xe5\xa4\x84\xe7\x90\x86',
#  b'\xe5\xa4\x8d\xe6\x9d\x82',
#  b'\xe5\xa4\x9a',
#  b'\xe5\xa4\x9a\xe5\xb0\x91',
#  b'\xe5\xa4\x9a\xe6\x95\xb0',
#  b'\xe5\xa4\x9a\xe6\xac\xa1',
#  b'\xe5\xa4\xa7\xe5\x8a\x9b',
#  b'\xe5\xa4\xa7\xe5\xa4\x9a\xe6\x95\xb0',
#  b'\xe5\xa4\xa7\xe5\xa4\xa7',
#  b'\xe5\xa4\xa7\xe5\xae\xb6',
#  b'\xe5\xa4\xa7\xe6\x89\xb9',
#  b'\xe5\xa4\xa7\xe7\xba\xa6',
#  b'\xe5\xa4\xa7\xe9\x87\x8f',
#  b'\xe5\xa4\xb1\xe5\x8e\xbb',
#  b'\xe5\xa5\xb9',
#  b'\xe5\xa5\xb9\xe4\xbb\xac',
#  b'\xe5\xa5\xb9\xe7\x9a\x84',
#  b'\xe5\xa5\xbd\xe7\x9a\x84',
#  b'\xe5\xa5\xbd\xe8\xb1\xa1',
#  b'\xe5\xa6\x82',
#  b'\xe5\xa6\x82\xe4\xb8\x8a\xe6\x89\x80\xe8\xbf\xb0',
#  b'\xe5\xa6\x82\xe4\xb8\x8b',
#  b'\xe5\xa6\x82\xe4\xbd\x95',
#  b'\xe5\xa6\x82\xe5\x85\xb6',
#  b'\xe5\xa6\x82\xe6\x9e\x9c',
#  b'\xe5\xa6\x82\xe6\xad\xa4',
#  b'\xe5\xa6\x82\xe8\x8b\xa5',
#  b'\xe5\xad\x98\xe5\x9c\xa8',
#  b'\xe5\xae\x81',
#  b'\xe5\xae\x81\xe5\x8f\xaf',
#  b'\xe5\xae\x81\xe6\x84\xbf',
#  b'\xe5\xae\x81\xe8\x82\xaf',
#  b'\xe5\xae\x83',
#  b'\xe5\xae\x83\xe4\xbb\xac',
#  b'\xe5\xae\x83\xe4\xbb\xac\xe7\x9a\x84',
#  b'\xe5\xae\x83\xe7\x9a\x84',
#  b'\xe5\xae\x89\xe5\x85\xa8',
#  b'\xe5\xae\x8c\xe5\x85\xa8',
#  b'\xe5\xae\x8c\xe6\x88\x90',
#  b'\xe5\xae\x9e\xe7\x8e\xb0',
#  b'\xe5\xae\x9e\xe9\x99\x85',
#  b'\xe5\xae\xa3\xe5\xb8\x83',
#  b'\xe5\xae\xb9\xe6\x98\x93',
#  b'\xe5\xaf\x86\xe5\x88\x87',
#  b'\xe5\xaf\xb9',
#  b'\xe5\xaf\xb9\xe4\xba\x8e',
#  b'\xe5\xaf\xb9\xe5\xba\x94',
#  b'\xe5\xb0\x86',
#  b'\xe5\xb0\x91\xe6\x95\xb0',
#  b'\xe5\xb0\x94\xe5\x90\x8e',
#  b'\xe5\xb0\x9a\xe4\xb8\x94',
#  b'\xe5\xb0\xa4\xe5\x85\xb6',
#  b'\xe5\xb0\xb1',
#  b'\xe5\xb0\xb1\xe6\x98\xaf',
#  b'\xe5\xb0\xb1\xe6\x98\xaf\xe8\xaf\xb4',
#  b'\xe5\xb0\xbd',
#  b'\xe5\xb0\xbd\xe7\xae\xa1',
#  b'\xe5\xb1\x9e\xe4\xba\x8e',
#  b'\xe5\xb2\x82\xe4\xbd\x86',
#  b'\xe5\xb7\xa6\xe5\x8f\xb3',
#  b'\xe5\xb7\xa8\xe5\xa4\xa7',
#  b'\xe5\xb7\xa9\xe5\x9b\xba',
#  b'\xe5\xb7\xb1',
#  b'\xe5\xb7\xb2\xe7\xbb\x8f',
#  b'\xe5\xb8\xae\xe5\x8a\xa9',
#  b'\xe5\xb8\xb8\xe5\xb8\xb8',
#  b'\xe5\xb9\xb6',
#  b'\xe5\xb9\xb6\xe4\xb8\x8d',
#  b'\xe5\xb9\xb6\xe4\xb8\x8d\xe6\x98\xaf',
#  b'\xe5\xb9\xb6\xe4\xb8\x94',
#  b'\xe5\xb9\xb6\xe6\xb2\xa1\xe6\x9c\x89',
#  b'\xe5\xb9\xbf\xe5\xa4\xa7',
#  b'\xe5\xb9\xbf\xe6\xb3\x9b',
#  b'\xe5\xba\x94\xe5\xbd\x93',
#  b'\xe5\xba\x94\xe7\x94\xa8',
#  ...]

# %%
stopwords = [line.strip() for line in open('./dic/stopword.txt', 'r',encoding = 'utf-8').readlines()]
stopwords
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-8310119f8364> in <module>
# ----> 1 stopwords = [line.strip() for line in open('./dic/stopword.txt', 'r').readlines()]
#       2 stopwords
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0x9c in position 9: illegal multibyte sequence
